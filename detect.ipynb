# %% [markdown]
# <a href="https://colab.research.google.com/github/ekaagragupta/roadDamageDetection/blob/main/detect.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install ultralytics roboflow opencv-python-headless matplotlib

# Verify installation
import ultralytics
ultralytics.checks()

print("✅ Environment ready!")
# Out:
# Ultralytics 8.4.6 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 38.9/112.6 GB disk)
# ✅ Environment ready!

# %%
from ultralytics import YOLO
from roboflow import Roboflow
import google.colab as files
import cv2
import matplotlib.pyplot as plt
import os
from IPython.display import Image , display
import shutil

#for reproducibility
import random
import numpy as np
import torch

# Setting seed = same results every time
SEED= 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

print("imported lib")
# Out:
# imported lib

# %%
from google.colab import files
import zipfile
import os

print("📤 Click 'Choose Files' button that appears below")
print("⏳ Upload will take 2-3 minutes (be patient!)")

# This opens file picker
uploaded = files.upload()

print("\n Upload complete!")

# Get the uploaded filename
zip_filename = list(uploaded.keys())[0]

# Extract the zip
with zipfile.ZipFile(zip_filename, 'r') as zip_ref:
    zip_ref.extractall("dataset")

print("Dataset extracted to 'dataset' folder!")

# Show what's inside
print("\n Dataset contents:")
for item in os.listdir("dataset"):
    print(f"  - {item}")
# Out:
# 📤 Click 'Choose Files' button that appears below
# ⏳ Upload will take 2-3 minutes (be patient!)
#      <input type="file" id="files-b4d45725-bea3-4466-90bf-e07157601630" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b4d45725-bea3-4466-90bf-e07157601630">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# ...
